# %% [markdown]
# # Deploying the Hybrid Test Bench Digital Twin Service
#
# In this notebook we will deploy a service that emulates the Hybrid Test Bench DT, and subsequently create a service to store data into the time series database.
#
# To get our service running do the followning:
# 1. Make sure you're in the root of our repository ([hybrid-test-bench](./))
# 2. Run the following command:
#
# ```bash
#     python -m startup.start_services
#    ```
#
# This will start both InfluxDB and RabbitMQ services. This way we can have a consistent environment accross all machines.
#
# Local sites, usernames and passwords are the following:
#
# - **InfluxDB:**
#   - Local site: [http://localhost:8086/](http://localhost:8086/)
#   - User: bench
#   - Password: hybridtestbench
#
# - **RabbitMQ:**
#   - Local site: [http://localhost:15672/](http://localhost:15672/)
#   - User: bench
#   - Password: bench
#
# Now you should be able to access these two services, and we'll continue from here.

# %% [markdown]
# ## Hybrid Test Bench Digital Twin Service
#
# The interface of the emulator is very similar to the example for the Incubator ([IncubatorDTCourse\1-Incubator-Service\1-Incubator-Service.ipynb](..\1-Incubator-Service\1-Incubator-Service.ipynb)).
#
# 1. We create the **dt_service.py**, which produces RabbitMQ messages that contain data that simulates a Digital Twin of the Hybrid Test Bench.
#
# 2. We create the **dt_htb_data_recorder_influx.py**, which deploys a service that subscribes to all relevant messages being exchanged, and stores them in the time series database, so that it can be visualized.
#
# **In the end**, we check that both services are running and we check the data coming to the InfluxDB dashboard. We then send a message, that will affect the behaviour of the emulator and we will be able to see the change in the InfluxDB dashboard.
#
# Run the next two code blocks to set up the environment and configure the logging:

# %%
# %%writefile logging.conf
#
# [loggers]
# keys=root,PTModel,PTEmulatorService,HybridTestBenchDataRecorderInflux,CalibrationService
#
# [handlers]
# keys=consoleHandler,PTModelFileHandler,PTEmulatorServiceFileHandler,HybridTestBenchDataRecorderInfluxFileHandler,CalibrationServiceHandler
#
# [formatters]
# keys=simpleFormatter
#
# [logger_root]
# level=DEBUG
# handlers=consoleHandler
#
# [logger_PTModel]
# level=DEBUG
# handlers=PTModelFileHandler
# qualname=PTModel
# propagate=0
#
# [logger_PTEmulatorService]
# level=DEBUG
# handlers=PTEmulatorServiceFileHandler
# qualname=PTEmulatorService
# propagate=0
#
# [logger_HybridTestBenchDataRecorderInflux]
# level=DEBUG
# handlers=HybridTestBenchDataRecorderInfluxFileHandler
# qualname=HybridTestBenchDataRecorderInflux
# propagate=0
#
# [logger_CalibrationService]
# level=DEBUG
# handlers=CalibrationServiceHandler
# qualname=CalibrationService
# propagate=0
#
# [handler_consoleHandler]
# class=StreamHandler
# formatter=simpleFormatter
# args=(sys.stdout,)
#
# [handler_PTModelFileHandler]
# class=FileHandler
# formatter=simpleFormatter
# args=('PTModel.log', 'w')
#
# [handler_PTEmulatorServiceFileHandler]
# class=FileHandler
# formatter=simpleFormatter
# args=('PTEmulatorService.log', 'w')
#
# [handler_HybridTestBenchDataRecorderInfluxFileHandler]
# class=FileHandler
# formatter=simpleFormatter
# args=('HybridTestBenchDataRecorderInflux.log', 'w')
#
# [handler_DT_HTB_DataRecorderInfluxFileHandler]
# class=FileHandler
# formatter=simpleFormatter
# args=('DT_HTB_DataRecorderInflux.log', 'w')
#
# [handler_CalibrationServiceHandler]
# class=FileHandler
# formatter=simpleFormatter
# args=('CalibrationService.log', 'w')
#
# [formatter_simpleFormatter]
# format=%(asctime)s.%(msecs)03d %(levelname)s %(name)s : %(message)s
# datefmt=%Y-%m-%d %H:%M:%S
# Out:
# Overwriting logging.conf

# %%
import sys
import os

# Get the current working directory. Should be hybrid-test-bench
current_dir = os.getcwd()

assert os.path.basename(current_dir) == 'hybrid-test-bench', 'Current directory is not hybrid-test-bench'

# Get the parent directory. Should be the root of the repository
parent_dir = current_dir

# The root of the repo should contain the startup folder. Otherwise something went wrong during the inital setup.
assert os.path.exists(os.path.join(parent_dir, 'startup')), 'startup folder not found in the repository root'

# The root of the repo should contain the installation folder. Otherwise something went wrong during the inital setup.
assert os.path.exists(os.path.join(parent_dir, 'installation')), 'installation folder not found in the repository root'

bench_startup_dir = os.path.join(parent_dir, 'startup')

assert os.path.exists(bench_startup_dir), 'hybrid-test-bench startup directory not found'

# Add the parent directory to sys.path
sys.path.append(bench_startup_dir)

# %% [markdown]
# Now that we have set up our environment, we continue by creating the DT_service script:

# %%
# %%writefile dt_service.py









# To-do: This needs to be rewritten! We don't need the pt_emulate part?









# Configure python path to load hybrid test bench modules
import sys
import os
import logging
import logging.config
import time
import numpy as np
from math import *

from scipy.integrate import solve_ivp

# Get the current working directory. Should be hybrid-test-bench
current_dir = os.getcwd()

assert os.path.basename(current_dir) == 'hybrid-test-bench', 'Current directory is not hybrid-test-bench'

# Get the parent directory. Should be the root of the repository
parent_dir = current_dir

from communication.server.rabbitmq import Rabbitmq
from communication.shared.protocol import ROUTING_KEY_STATE, ROUTING_KEY_FORCES
import dt_model as dt_model
import calibration_service as cal_service
import actuator_controller as actuator_controller

class DTService:
    
    def __init__(self, uh_initial, uv_initial, lh_initial, lv_initial, max_vertical_displacement, execution_interval, rabbitmq_config):
        # Initialize the DTService with initial values and configuration
        self._l = logging.getLogger("DTService")
        self._l.info("Initializing DTService.")

        self._rabbitmq = Rabbitmq(**rabbitmq_config)
        
        self.uh = uh_initial
        self.uv = uv_initial
        self.lh = lh_initial
        self.lv = lv_initial

        self.vertical_frequency = 0.0
        self.horizontal_frequency = 0.0

        self.lh_wanted = 100
        self.uv_wanted = 100

        self.max_vertical_displacement = max_vertical_displacement
        self._execution_interval = execution_interval # seconds
        self._force_on = 0.0
        self.E_modulus = 100e3 # Pa (example value for aluminum)

        try:
            self.DT_Model = dt_model.DTModel()
            self.calibration_service = cal_service.CalibrationService(self.DT_Model)
        except Exception as e:
            self._l.error("Failed to initialize DTModel: %s", e, exc_info=True)
            raise

        try:
            self.ac = actuator_controller.ActuatorController(self.lh_wanted, self.uv_wanted, self.vertical_frequency, self.horizontal_frequency, self._execution_interval)
        except Exception as e:
            self._l.error("Failed to initialize ActuatorController: %s", e, exc_info=True)
            raise

        self.DT_Model.set_beampars(16, 'E', self.E_modulus) # Set the beam parameters for the PT model  

    def setup(self):
        self._rabbitmq.connect_to_server()

        # Declare local queues for the force messages
        self.forces_queue_name = self._rabbitmq.declare_local_queue(routing_key=ROUTING_KEY_FORCES)

        self._l.info(f"DTService setup complete.")

    def _read_forces(self):
        # Read the forces from the RabbitMQ queue
        msg = self._rabbitmq.get_message(self.forces_queue_name)

        if msg is not None:
            return msg
        else:
            return None
    
    def check_control_commands(self):
        # Check if there are control commands
        force_cmd = self._read_forces()
        #self._l.debug(f"Control command: {force_cmd}")
        if force_cmd is not None:
            if 'forces' in force_cmd and force_cmd['forces'] is not None:
                self._l.info("Force command: %s", force_cmd["forces"])
                self._force_on = 1.0 if force_cmd["forces"] else 0.0

            if "horizontal_force" in force_cmd and force_cmd["horizontal_force"] is not None:
                self._l.info(f"Horizontal force command: {force_cmd['horizontal_force']}")
                self.lh_wanted = force_cmd["horizontal_force"]

            if "vertical_displacement" in force_cmd and force_cmd["vertical_displacement"] is not None:
                self._l.info(f"Vertical force command: {force_cmd['vertical_displacement']}")
                self.uv_wanted = force_cmd["vertical_displacement"]
                
            if "vertical_frequency" in force_cmd and force_cmd["vertical_frequency"] is not None:
                self._l.info(f"Vertical frequency command: {force_cmd['vertical_frequency']}")
                self.vertical_frequency = force_cmd["vertical_frequency"]
                
            if "horizontal_frequency" in force_cmd and force_cmd["horizontal_frequency"] is not None:
                self._l.info(f"Horizontal frequency command: {force_cmd['horizontal_frequency']}")
                self.horizontal_frequency = force_cmd["horizontal_frequency"]


    def emulate_pt(self):
        # Emulate the PT behavior based on the control commands

        # Additional logic for the emulator can go here
        # the if statement is just hardcoded emulator behaviour for now! 
        # _uh, _uv, _lh, _lv, and _r need to be extracted from the simulation results (u, lf, r)
        if self._force_on == 1.0:
            try:
                self._uh, self._uv, self._lh, self._lv = self.ac.step_simulation(self.PT_Model)
            except Exception as e:
                self._l.error("Failed to emulate PT behavior: %s", e, exc_info=True)
                raise

            try:
                disp = self.PT_Model.get_displacements()
                self.calibration_service.set_calibration_displacement(disp) # Set the displacements in the calibration service
                self.calibration_service.calibrate_model() # Call the calibration service to calibrate the model
            except Exception as e:
                self._l.error("Calibration service failed: %s", e, exc_info=True)
                raise
        else:
            # Horizontal displacement
            self._uh = 0.0
            # Vertical displacement
            self._uv = 0.0
            # Horizontal force
            self._lh = 0.0
            # Vertical force
            self._lv = 0.0
            # Restoring force
            # self._r = r[something] # in case we need this for the emulator, we can put it here

        self.E_modulus = self.PT_Model.get_beampars(16).E # Get the E modulus from the PT model
        self.PT_Model.set_beampars(16, 'E', self.E_modulus) # Set the E modulus in the PT model
        #self._l.info("PT script executed successfully.")
        
    def send_state(self, time_start):
        #self._l.info("Sending state to hybrid test bench physical twin.")
        timestamp = time.time_ns()
        # Publishes the new state
        message = {
            "measurement": "emulator",
            "time": timestamp,
            "tags": {
                "source": "emulator"
            },
            "fields": {
                "horizontal_displacement": self._uh,
                "vertical_displacement": self._uv,
                "horizontal_force": self._lh,
                "vertical_force": self._lv,
                "E_modulus": self.E_modulus,
                # "restoring_force": self._r,
                "force_on": self._force_on,
                "max_vertical_displacement": self.max_vertical_displacement,
                "execution_interval": self._execution_interval,
                "elapsed": time.time() - time_start,
            }
        }

        self._rabbitmq.send_message(ROUTING_KEY_STATE, message)
        #self._l.debug(f"Message sent to {ROUTING_KEY_STATE}.")
        #self._l.debug(message)
    
    def start_emulation(self):
        # Start the emulation loop
        self._l.info("Starting PTEmulator emulation loop.")
        try:
            while True:
                #self._l.debug("Emulation loop iteration.")
                time_start = time.time()
                #Check if there are control commands
                self.check_control_commands()
                # Emulate the PT behavior
                self.emulate_pt() 
                # Send the new state to the hybrid test bench physical twin
                self.send_state(time_start)
                # Sleep until the next sample
                time_end = time.time()
                time_diff = time_end - time_start
                if time_diff < self._execution_interval:
                    time.sleep(self._execution_interval - time_diff)
                else:
                    self._l.warning(f"Emulation loop took too long: {time_diff} seconds.")
        except KeyboardInterrupt:
            self._l.info("Emulation loop interrupted by user.")
        except Exception as e:
            self._l.error("Emulation loop failed: %s", e, exc_info=True)
    
if __name__ == "__main__":
    # Get utility functions to config logging and load configuration
    from pyhocon import ConfigFactory
    
    logging_conf = os.path.join(os.path.dirname(os.getcwd()), 'hybrid-test-bench', 'logging.conf')
    logging.config.fileConfig(logging_conf)

    # Get path to the startup.conf file used in the hybrid test bench PT & DT:
    startup_conf = os.path.join(os.path.dirname(os.getcwd()), 'hybrid-test-bench', 'software','startup.conf')
    assert os.path.exists(startup_conf), 'startup.conf file not found'

    # The startup.conf comes from the hybrid test bench repository.
    config = ConfigFactory.parse_file(startup_conf)
    
    service = PTEmulatorService(
        uh_initial = 0.0,
        uv_initial = 0.0,
        lh_initial = 0.0,
        lv_initial = 0.0,
        # r_initial = 0.0,
        max_vertical_displacement = 70.0,
        execution_interval = 3.0,
        rabbitmq_config=config["rabbitmq"])

    service.setup()
    
    # Start the PTEmulatorService
    service.start_emulation()
# Out:
# Writing dt_service.py

# %% [markdown]
# And we continue by creating the dt_htb_data_recorder_influx script:
#
# The key parts of this service are:
# 1. It subscribes to all messages going to a topic that's prefixed by `ROUTING_KEY_RECORDER="hybridtestbench.record.#"`. So a message sent to topic `hybridtestbench.record.driver.state` will also be received by the data recorder. Note that any other service that has declared a local queue attached to that topic will receive a copy of the message.
# 2. It uses the InfluxDB Client library to write the message data into the time series database. The message is already in the right format.

# %%
# %%writefile dt_htb_data_recorder_influx.py

# Configure python path to load incubator modules
import sys
import os
import logging
import logging.config
import time

from influxdb_client import InfluxDBClient
from influxdb_client.client.write_api import SYNCHRONOUS

# Get the current working directory. Should be hybrid-test-bench
current_dir = os.getcwd()

assert os.path.basename(current_dir) == 'hybrid-test-bench', 'Current directory is not hybrid-test-bench'

# Get the parent directory. Should be the root of the repository
parent_dir = current_dir

# The root of the repo should contain the startup folder. Otherwise something went wrong during the inital setup.
assert os.path.exists(os.path.join(parent_dir, 'startup')), 'startup folder not found in the repository root'

# The root of the repo should contain the installation folder. Otherwise something went wrong during the inital setup.
assert os.path.exists(os.path.join(parent_dir, 'installation')), 'installation folder not found in the repository root'

bench_startup_dir = os.path.join(parent_dir, 'startup')

assert os.path.exists(bench_startup_dir), 'hybrid-test-bench startup directory not found'

# Add the parent directory to sys.path
sys.path.append(bench_startup_dir)

from communication.shared.protocol import ROUTING_KEY_RECORDER
from communication.server.rabbitmq import Rabbitmq
import numpy as np

class DtHtbDataRecorderInflux:
    def __init__(self, rabbitmq_config, influxdb_config):
        self._l = logging.getLogger("DT_HTB_DataRecorderInflux")
        self._l.info("Initializing DT_HTB_DataRecorderInflux.")
        self._l.info("Connecting to InfluxDB...")    
        client = InfluxDBClient(**influxdb_config)
        write_api = client.write_api(write_options=SYNCHRONOUS)
        self.write_api = write_api
        self.influx_db_org = influxdb_config["org"]
        self.influxdb_bucket = influxdb_config["bucket"]

        self.rabbitmq = Rabbitmq(**rabbitmq_config)

    def read_record_request(self, ch, method, properties, body_json):
        self._l.debug("New record msg:")
        self._l.debug(body_json)
        try:
            self.write_api.write(self.influxdb_bucket, self.influx_db_org, body_json)
        except Exception as e:
            self._l.error("Failed to write to InfluxDB: %s", e, exc_info=True)
            raise

    def setup(self):
        self._l.info("Setting up DT_HTB_DataRecorderInflux.")
        self.rabbitmq.connect_to_server()

        self.rabbitmq.subscribe(routing_key=ROUTING_KEY_RECORDER,
                           on_message_callback=self.read_record_request)

    def start_recording(self):
        self._l.info("Starting DT_HTB_DataRecorderInflux.")
        try:
            self.rabbitmq.start_consuming()
        except KeyboardInterrupt:
            self.rabbitmq.close()
    
if __name__ == "__main__":
    # Get utility functions to config logging and load configuration
    from pyhocon import ConfigFactory

    # Get logging configuration
    logging.config.fileConfig("logging.conf")

    # Get path to the startup.conf file used in the hybrid test bench PT & DT:
    startup_conf = os.path.join(os.path.dirname(os.getcwd()), 'hybrid-test-bench', 'software','startup.conf')
    assert os.path.exists(startup_conf), 'startup.conf file not found'

    # The startup.conf comes from the hybrid test bench repository.
    config = ConfigFactory.parse_file(startup_conf)
    
    service = HybridTestBenchDataRecorderInflux(rabbitmq_config=config["rabbitmq"], influxdb_config=config["influxdb"])

    service.setup()
    
    # Start the HybridTestBenchDataRecorderInflux
    service.start_recording()
# Out:
# Writing dt_htb_data_recorder_influx.py

# %% [markdown]
# Now we will run both scripts.
#
# First the DT_service:

# %%
# You can run this, or you can run the command below in a new terminal windows to start the service
import subprocess
import time

# Start a process asynchronously
dt_service_proc = subprocess.Popen([sys.executable, "dt_service.py"])

# Wait for 5 seconds for the process to start
time.sleep(5)

# Print the PID of the process. You can search for this in your task manager to see the process running and kill it if necessary.
print(f"dt_service = {dt_service_proc.pid}")
# Out:
# pt_emulator_service = 14600

# %% [markdown]
# Then we run the dt_htb_data_recorder_influx:

# %%
# Start a process asynchronously
dt_htb_data_recorder_influx_proc = subprocess.Popen([sys.executable, "dt_htb_data_recorder_influx.py"])

# Wait for 5 seconds for the process to start
time.sleep(5)

# Print the PID of the process. You can search for this in your task manager to see the process running and kill it if necessary.
print(f"dt_htb_data_recorder_influx = {dt_htb_data_recorder_influx_proc.pid}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Start a process asynchronously
# ----> 2 dt_htb_data_recorder_influx_proc = subprocess.Popen([sys.executable, "dt_htb_data_recorder_influx.py"])
#       4 # Wait for 5 seconds for the process to start
#       5 time.sleep(5)
#
# NameError: name 'subprocess' is not defined

# %% [markdown]
# Now we check that both services are running:

# %%
assert dt_service_proc.poll() is None, "DTService process has crashed"
assert dt_htb_data_recorder_influx_proc.poll() is None, "DT_HTB_DataRecorderInflux process has crashed"

# %% [markdown]
# We verify that the DT_service is running by printing the log file:

# %%
# Print contents of log file to verify that the service is running
with open('DTService.log', 'r') as f:
    print(f.read())

# Check process hasn't crashed
assert dt_service_proc.poll() is None, "DTService process has crashed"

# %% [markdown]
# We verify that the dt_htb_data_recorder_influx is running by printing the log file:

# %%
# Print contents of log file to verify that the service is running
with open('DT_HTB_DataRecorderInflux.log', 'r') as f:
    print(f.read())
# Out:
# 2025-05-21 11:40:57.387 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 11:40:57.387 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747820457341460400, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': 0.002154699931908103, 'vertical_displacement': -8.418496953860965, 'horizontal_force': 30.72862223611989, 'vertical_force': -6.7176251440011105, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.3798394203186035}}
# 2025-05-21 11:41:00.425 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 11:41:00.427 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747820460376520000, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': 0.0012838783389494124, 'vertical_displacement': -0.5765893250011546, 'horizontal_force': 15.463753212632197, 'vertical_force': -0.4597617157474262, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.4094123840332031}}
# 2025-05-21 11:41:03.456 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 11:41:03.456 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747820463408138800, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': 0.00038005425878088214, 'vertical_displacement': 7.254473368007053, 'horizontal_force': -0.18216343292285853, 'vertical_force': 5.78943738213018, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.4260990619659424}}
# 2025-05-21 11:41:06.416 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 11:41:06.416 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747820466372207400, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': -0.0005253810522375902, 'vertical_displacement': 15.072986858943098, 'horizontal_force': -15.83897837055181, 'vertical_force': 12.028621300788313, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.3831820487976074}}
# 2025-05-21 11:41:09.470 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 11:41:09.470 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747820469421721900, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': -0.0014022076347131106, 'vertical_displacement': 22.780341286035796, 'horizontal_force': -31.08819341382361, 'vertical_force': 18.179104761815456, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.42825794219970703}}
# 2025-05-21 11:41:12.465 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 11:41:12.465 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747820472416091200, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': -0.0022216980735725953, 'vertical_displacement': 30.347738773528654, 'horizontal_force': -45.57360933165316, 'vertical_force': 24.217914477599237, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.4165501594543457}}
# 2025-05-21 11:41:15.457 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 11:41:15.457 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747820475404205400, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': -0.0029559453136663704, 'vertical_displacement': 37.72817562988512, 'horizontal_force': -58.937001098981874, 'vertical_force': 30.107548036090943, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.39756011962890625}}
# 2025-05-21 11:41:18.506 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 11:41:18.506 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747820478461527900, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': -0.0035794347899050474, 'vertical_displacement': 44.876095247014156, 'horizontal_force': -70.84919904830763, 'vertical_force': 35.811657146528454, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.4437417984008789}}
# 2025-05-21 11:41:21.520 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 11:41:21.520 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747820481474170400, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': -0.004069618351627641, 'vertical_displacement': 51.74741899002459, 'horizontal_force': -81.01685620019614, 'vertical_force': 41.295072122053156, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.44907712936401367}}
# 2025-05-21 11:41:24.464 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 11:41:24.464 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747820484415245200, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': -0.004407508811659619, 'vertical_displacement': 58.29978456371111, 'horizontal_force': -89.18959074298245, 'vertical_force': 46.52399193005011, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.3873748779296875}}
# 2025-05-21 11:41:27.475 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 11:41:27.476 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747820487422920900, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': -0.004578192660477862, 'vertical_displacement': 64.4927986196267, 'horizontal_force': -95.16617602440637, 'vertical_force': 51.46618563096929, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.3914937973022461}}
# 2025-05-21 11:41:30.475 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 11:41:30.475 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747820490425064300, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': -0
 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': -0.013141192377130972, 'vertical_displacement': -85.01936584384143, 'horizontal_force': -99.99674170197433, 'vertical_force': -67.85231280297265, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.38679051399230957}}
# 2025-05-21 11:43:45.866 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 11:43:45.866 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747820625815843500, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': -0.013235972208633276, 'vertical_displacement': -88.88685194688205, 'horizontal_force': -98.63186114158114, 'vertical_force': -70.9387310480193, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.3904075622558594}}
# 2025-05-21 11:43:49.006 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 11:43:49.006 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747820628957926400, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': -0.013094320586301486, 'vertical_displacement': -92.20632013966859, 'horizontal_force': -94.83862871892863, 'vertical_force': -73.58774224657346, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.5209627151489258}}
# 2025-05-21 11:43:51.986 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 11:43:51.987 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747820631936141500, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': -0.012723065534843397, 'vertical_displacement': -94.95721086578342, 'horizontal_force': -88.71049859223183, 'vertical_force': -75.7829411514787, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.4883127212524414}}
# 2025-05-21 11:43:54.893 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 11:43:54.893 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747820634851567100, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': -0.012134083900555094, 'vertical_displacement': -97.12257021047411, 'horizontal_force': -80.39797092154356, 'vertical_force': -77.51080142711197, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.40169429779052734}}
# 2025-05-21 11:43:57.935 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 11:43:57.935 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747820637884018800, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': -0.011344056414924024, 'vertical_displacement': -98.68905688838561, 'horizontal_force': -70.10570798691359, 'vertical_force': -78.76068115394759, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.4239373207092285}}
# 2025-05-21 11:44:00.955 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 11:44:00.955 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747820640907659800, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': -0.010374019988352247, 'vertical_displacement': -99.64702526272856, 'horizontal_force': -58.087216956996514, 'vertical_force': -79.52488894931597, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.4354579448699951}}
# 2025-05-21 11:44:03.916 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 11:44:03.916 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747820643862603700, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': -0.009248834587770387, 'vertical_displacement': -99.990733741654, 'horizontal_force': -44.63844889485243, 'vertical_force': -79.79885011857587, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.3851945400238037}}
# 2025-05-21 11:44:07.055 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 11:44:07.055 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747820646997246900, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': -0.008011533283766414, 'vertical_displacement': -99.99286989173048, 'horizontal_force': -30.090528811885175, 'vertical_force': -79.80019159836733, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.5182983875274658}}
# 2025-05-21 11:44:09.996 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 11:44:09.997 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747820649947057100, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': -0.00669559657623312, 'vertical_displacement': -99.7086977030337, 'horizontal_force': -14.801650041600155, 'vertical_force': -79.5730258325068, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.4652740955352783}}
# 2025-05-21 11:44:13.005 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 11:44:13.005 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747820652953826900, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': -0.005315281839831753, 'vertical_displacement': -98.81237397757812, 'horizontal_force': 0.8516925609083223, 'vertical_force': -78.85732263344757, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.4660041332244873}}
# 2025-05-21 11:44:16.095 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 11:44:16.096 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747820656043572700, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': -0.003903462232954417, 'vertical_displacement': -97.30686127581444, 'horizontal_force': 16.48491903853585, 'vertical_force': -77.65545587980401, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.5529673099517822}}
# 2025-05-21 11:44:19.084 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 11:44:19.084 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747820659032372000, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': -0.0024935959966688208, 'vertical_displacement': -95.20144865298336, 'horizontal_force': 31.710626274030503, 'vertical_force': -75.9748483881039, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.5273973941802979}}
# 2025-05-21 11:44:22.010 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 11:44:22.010 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747820661964321400, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': -0.0011180802689812668, 'vertical_displacement': -92.5090896190165, 'horizontal_force': 46.15623516071545, 'vertical_force': -73.82584702755152, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.455643892288208}}
# 2025-05-21 11:44:24.965 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 11:44:24.965 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747820664916702900, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': 0.00019186951053279128, 'vertical_displacement': -89.2464137307089, 'horizontal_force': 59.46541595823174, 'vertical_force': -71.2217319355759, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0
 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.42692065238952637}}
# 2025-05-21 11:45:13.131 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 11:45:13.131 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747820713081967800, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': 0.0020733998602215876, 'vertical_displacement': 15.301304249040065, 'horizontal_force': 14.567688910828977, 'vertical_force': 12.211589579597236, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.4435312747955322}}
# 2025-05-21 11:45:16.090 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# ...
# 2025-05-21 12:47:48.914 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747824468859830000, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': -0.010414003676419769, 'vertical_displacement': -34.96343423346938, 'horizontal_force': -100.0214432968279, 'vertical_force': -27.905111926721627, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.47861742973327637}}
# 2025-05-21 12:47:51.882 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 12:47:51.882 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747824471838152200, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': -0.009944897968604606, 'vertical_displacement': -27.505514717087113, 'horizontal_force': -99.28707285558714, 'vertical_force': -21.953291193734305, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.4517509937286377}}
# 2025-05-21 12:47:55.073 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 12:47:55.073 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747824475026567400, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': -0.009266436877477992, 'vertical_displacement': -19.877869366538842, 'horizontal_force': -96.20017838944602, 'vertical_force': -15.865961792361087, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.6326935291290283}}
# 2025-05-21 12:47:57.833 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 12:47:57.833 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747824477785210200, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': -0.00837977797781387, 'vertical_displacement': -12.127246032201793, 'horizontal_force': -90.7444023320635, 'vertical_force': -9.68043049708689, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.39073610305786133}}
# 2025-05-21 12:48:00.902 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 12:48:00.902 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747824480857739400, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': -0.007298952337867121, 'vertical_displacement': -4.300804726222791, 'horizontal_force': -83.05447241288148, 'vertical_force': -3.434336781400565, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.44748854637145996}}
# 2025-05-21 12:48:03.861 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 12:48:03.861 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747824483817795100, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': -0.006042340951486702, 'vertical_displacement': 3.5591217576304897, 'horizontal_force': -73.31935141149928, 'vertical_force': 2.8385308948226258, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.4063906669616699}}
# 2025-05-21 12:48:06.848 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 12:48:06.848 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747824486808227700, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': -0.0046352554600711205, 'vertical_displacement': 11.36242144155283, 'horizontal_force': -61.77885557764348, 'vertical_force': 9.0662525617165, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.38768744468688965}}
# 2025-05-21 12:48:09.961 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 12:48:09.962 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747824489913771200, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': -0.003100629273090687, 'vertical_displacement': 19.131836281703887, 'horizontal_force': -48.71718387161757, 'vertical_force': 15.266970370288197, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.4915428161621094}}
# 2025-05-21 12:48:12.932 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 12:48:12.932 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747824492876849200, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': -0.001470836277536084, 'vertical_displacement': 26.775314989307684, 'horizontal_force': -34.45593791928664, 'vertical_force': 21.367214638751957, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.4506406784057617}}
# 2025-05-21 12:48:16.111 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 12:48:16.111 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747824496060210800, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': 0.00022206629706883252, 'vertical_displacement': 34.25267855218174, 'horizontal_force': -19.346248208884486, 'vertical_force': 27.334911685928905, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.6232924461364746}}
# 2025-05-21 12:48:18.941 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 12:48:18.941 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747824498895966000, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': 0.0019441397156333242, 'vertical_displacement': 41.5185395926998, 'horizontal_force': -3.7580267793036377, 'vertical_force': 33.133830818810075, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.4447441101074219}}
# 2025-05-21 12:48:21.961 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 12:48:21.961 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747824501907327900, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': 0.0036601789004499907, 'vertical_displacement': 48.52828080384892, 'horizontal_force': 11.923432737938974, 'vertical_force': 38.72835551614899, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.45483899116516113}}
# 2025-05-21 12:48:25.120 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 12:48:25.121 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747824505067687500, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': 0.005334670023450673, 'vertical_displacement': 55.23874378351876, 'horizontal_force': 27.30827155681629, 'vertical_force': 44.08403342365892, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.6060454845428467}}
# 2025-05-21 12:48:28.009 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 12:48:28.009 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747824507962480500, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': 0.006933405956829965, 'vertical_displacement': 61.60857507451441, 'horizontal_force': 42.02083647210634, 'vertical_force': 49.16785298043254, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.48800110816955566}}
# 2025-05-21 12:48:30.971 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 12:48:30.971 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747824510925761000, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': 0.008423426169021106, 'vertical_displacement': 67.59850563139291, 'horizontal_force': 55.69879376597518, 'vertical_force': 53.94846642567337, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.4453921318054199}}
# 2025-05-21 12:48:33.979 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 12:48:33.980 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747824513932394500, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': 0.009774065003602225, 'vertical_displacement': 73.17160070646698, 'horizontal_force': 68.00529360374823, 'vertical_force': 58.39638952431966, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.44513559341430664}}
# 2025-05-21 12:48:36.933 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 12:48:36.940 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747824516893625100, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': 0.010957671668672985, 'vertical_displacement': 78.29349245560827, 'horizontal_force': 78.63728539477358, 'vertical_force': 62.48418740604349, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.39501476287841797}}
# 2025-05-21 12:48:40.078 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 12:48:40.078 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747824520029286700, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': 0.011950254139736141, 'vertical_displacement': 82.93259487658901, 'horizontal_force': 87.33295015422877, 'vertical_force': 66.18664628266593, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.5262913703918457}}
# 2025-05-21 12:48:42.990 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 12:48:42.990 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747824522936826100, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': 0.012732040615262426, 'vertical_displacement': 87.06030020305232, 'horizontal_force': 93.87817586752638, 'vertical_force': 69.48093034233936, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.428189754486084}}
# 2025-05-21 12:48:46.189 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 12:48:46.190 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747824526134130600, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': 0.013287937427818287, 'vertical_displacement': 90.651155538519, 'horizontal_force': 98.11182708071263, 'vertical_force': 72.3467228441013, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.6168947219848633}}
# 2025-05-21 12:48:49.086 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 12:48:49.086 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747824529044505400, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': 0.013607899978789533, 'vertical_displacement': 93.68301949045853, 'horizontal_force': 99.93000608636535, 'vertical_force': 74.76635122633466, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.5179619789123535}}
# 2025-05-21 12:48:52.069 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 12:48:52.069 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747824532018286600, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': 0.013749488946838114, 'vertical_displacement': 96.13717580682206, 'horizontal_force': 100.02143277568949, 'vertical_force': 76.724896157777, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.4902822971343994}}
# 2025-05-21 12:48:55.188 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 12:48:55.189 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747824535138176500, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': 0.013788510318280309, 'vertical_displacement': 97.99853011244134, 'horizontal_force': 99.2870096646522, 'vertical_force': 78.21033404917495, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.5996012687683105}}
# 2025-05-21 12:48:58.018 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 12:48:58.018 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747824537970800100, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': 0.013594486965176589, 'vertical_displacement': 99.25573535816426, 'horizontal_force': 96.20003313732106, 'vertical_force': 79.21357124968476, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.42928457260131836}}
# 2025-05-21 12:49:01.017 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 12:49:01.018 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747824540968896000, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': 0.013165601239164491, 'vertical_displacement': 99.90092100698875, 'horizontal_force': 90.74417884237346, 'vertical_force': 79.72832625934763, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.4223058223724365}}
# 2025-05-21 12:49:04.068 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 12:49:04.068 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747824544016717000, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': 0.012517022598385052, 'vertical_displacement': 100.00212312828373, 'horizontal_force': 83.0541761556681, 'vertical_force': 79.80889871638784, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.4614274501800537}}
# 2025-05-21 12:49:07.048 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 12:49:07.048 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747824547000631900, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': 0.011684736524489857, 'vertical_displacement': 99.924542716258, 'horizontal_force': 73.31898968878247, 'vertical_force': 79.74674246909507, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.43131279945373535}}
# 2025-05-21 12:49:10.038 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 12:49:10.038 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747824549992398100, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': 0.01067050219550808, 'vertical_displacement': 99.3263305928589, 'horizontal_force': 61.77843729846062, 'vertical_force': 79.26905032368143, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.42023396492004395}}
# 2025-05-21 12:49:13.114 DEBUG HybridTestBenchDataRecorderInflux : New record msg:
# 2025-05-21 12:49:13.114 DEBUG HybridTestBenchDataRecorderInflux : {'measurement': 'emulator', 'time': 1747824553065482800, 'tags': {'source': 'emulator'}, 'fields': {'horizontal_displacement': 0.009493487242683134, 'vertical_displacement': 98.11567715730833, 'horizontal_force': 48.71671933550254, 'vertical_force': 78.30256060532204, 'E_modulus': 100000.0, 'force_on': 1.0, 'max_vertical_displacement': 70.0, 'execution_interval': 3.0, 'elapsed': 0.4899420738220215}}

# %% [markdown]
# On the InfluxDB management page, you should be able to query for the data coming from the DT service:
#
# To-do: Insert image here

# %% [markdown]
# Next, we send the 'apply force' command, adjust the displacement, and modify the frequencies:

# %%
from communication.server.rabbitmq import Rabbitmq
from communication.shared.protocol import ROUTING_KEY_FORCES

from pyhocon import ConfigFactory

# Get config
startup_conf = os.path.join(os.path.dirname(os.getcwd()), 'hybrid-test-bench', 'software','startup.conf')
config = ConfigFactory.parse_file(startup_conf)

# Send a message to the DT to simulate the application of a force
with Rabbitmq(**config["rabbitmq"]) as rabbitmq:
    rabbitmq.send_message(ROUTING_KEY_FORCES, {"forces": True,
                                               "horizontal_force": 500, 
                                               "vertical_displacement": 250,
                                               "horizontal_frequency": 4.0,
                                               "vertical_frequency": 2.0})

# Wait a bit for the message to be processed
time.sleep(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 7
#       4 from pyhocon import ConfigFactory
#       6 # Get config
# ----> 7 startup_conf = os.path.join(os.path.dirname(os.getcwd()), 'hybrid-test-bench', 'software','startup.conf')
#       8 config = ConfigFactory.parse_file(startup_conf)
#      10 # Send a message to the DT to simulate the application of a force
#
# NameError: name 'os' is not defined

# %% [markdown]
# We can see the change in the dashboard:
#
# To-do: Insert image here

# %% [markdown]
# That's it for now.
#
# We can turn off the force application:

# %%
# Get config
startup_conf = os.path.join(os.path.dirname(os.getcwd()), 'hybrid-test-bench', 'software','startup.conf')
config = ConfigFactory.parse_file(startup_conf)

# Send a message to the DT to simulate the application of a force
with Rabbitmq(**config["rabbitmq"]) as rabbitmq:
    rabbitmq.send_message(ROUTING_KEY_FORCES, {"forces": False})

# Wait a bit for the message to be processed
time.sleep(5)

# %% [markdown]
# In this last step we kill both processes:

# %%
dt_service_proc.terminate() # Terminate the process. Send SIGTERM signal to the process. The process can catch this signal and perform cleanup operations before exiting, so we wait.
dt_service_proc.wait()  # Wait for the process to exit fully. Should print exit code 1, due to interruption.

# Ensure process has exited
assert dt_service_proc.returncode is not None, 'Process has not exited'

# %%
dt_htb_data_recorder_influx_proc.terminate() # Terminate the process. Send SIGTERM signal to the process. The process can catch this signal and perform cleanup operations before exiting, so we wait.
dt_htb_data_recorder_influx_proc.wait()  # Wait for the process to exit fully. Should print exit code 1, due to interruption.

# Ensure process has exited
assert dt_htb_data_recorder_influx_proc.returncode is not None, 'Process has not exited'
